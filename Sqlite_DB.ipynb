# %%
import pandas as pd

# denver airbnb review data
reviews_gz_df = pd.read_csv('reviews.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
reviews_gz_df.head()
# Out:
#    listing_id         id        date  reviewer_id reviewer_name  \
# 0         177   99461681  2016-09-04     78348548        Brenna
# 1         177  101460574  2016-09-13     72125554       Rachael
# 2         177  101681475  2016-09-14     21300329         Haley
# 3         177  102963808  2016-09-19     53882399          Mike
# 4         177  103447333  2016-09-22     94621370         Carol
#
#                                             comments
# 0  Great place to stay! Definitely a tiny home, b...
# 1  Joe was very friendly and gave us all the info...
# 2  Amazing property and Joe was a great host! Eve...
# 3  Joe was a great host, the description of this ...
# 4  He welcomes us when we first arrived and gave ...

# %%
# number of reviews per listing
review_counts_per_listing = reviews_gz_df.groupby('listing_id')['id'].nunique()
review_counts_per_listing.head(10)
# Out:
# listing_id
# 177       39
# 360       48
# 590      565
# 592      147
# 686      236
# 1940      34
# 2086      12
# 21745    226
# 31503     55
# 39405    549
# Name: id, dtype: int64

# %%
# denver airbnb calendar data
calendar_gz_df = pd.read_csv('calendar.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
calendar_gz_df.head(10)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0         177  2019-04-27         f   $51.00         $51.00               1
# 1         177  2019-04-28         f   $72.00         $72.00               1
# 2         177  2019-04-29         f   $64.00         $64.00               1
# 3         177  2019-04-30         f   $62.00         $62.00               1
# 4         177  2019-05-01         f   $65.00         $65.00               1
# 5         177  2019-05-02         f   $51.00         $51.00               1
# 6         177  2019-05-03         f   $55.00         $55.00               1
# 7         177  2019-05-04         f   $55.00         $55.00               1
# 8         177  2019-05-05         f   $51.00         $51.00               1
# 9     2466830  2019-04-27         f  $300.00        $300.00               1
#
#    maximum_nights
# 0             400
# 1             400
# 2             400
# 3             400
# 4             400
# ...

# %%
# denver airbnb listings data
listings_gz_df = pd.read_csv('listings.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
listings_gz_df.head()
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  177  https://www.airbnb.com/rooms/177  20190427155417   2019-04-27
# 1  360  https://www.airbnb.com/rooms/360  20190427155417   2019-04-27
# 2  590  https://www.airbnb.com/rooms/590  20190427155417   2019-04-27
# 3  592  https://www.airbnb.com/rooms/592  20190427155417   2019-04-27
# 4  686  https://www.airbnb.com/rooms/686  20190427155417   2019-04-27
#
#                                                name  \
# 0  Tiny Home in the Heart of the City- ECO FRIENDLY
# 1       LoHi Secret garden at the Chickadee Cottage
# 2                 Comfortable  - and a great value!
# 3                                           private
# 4                 Alexandra's Uptown Queen Bed Room
#
#                                              summary  \
# 0  160 sq ft + 80 sq ft loft for sleeping, Sleeps...
# 1  Come enjoy our oasis is the city and stay at o...
# 2  Large guest room in my home, where I also live...
# ...

# %%
# number of unique denver airbnb listings
len(listings_gz_df)
# Out:
# 4686

# %%
# denver airbnb neighborhoods data
neighbourhoods_df = pd.read_csv('neighbourhoods.csv')
neighbourhoods_df.head()
# Out:
#    neighbourhood_group neighbourhood
# 0                  NaN   Athmar Park
# 1                  NaN       Auraria
# 2                  NaN         Baker
# 3                  NaN        Barnum
# 4                  NaN   Barnum West

# %%
# number of denver neighborhoods in airbnb data
len(neighbourhoods_df)
# Out:
# 78

# %%
crime_df = pd.read_csv('denver_2019_crime.csv')
crime_df.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0  2.019279e+08  2.020000e+14          1208                       0
# 1  2.019238e+08  2.020000e+14          2404                       0
# 2  2.019260e+08  2.020000e+14          2303                       0
# 3  2.019600e+10  2.020000e+16          2999                       1
# 4  2.019291e+08  2.020000e+14          3504                       0
#
#              OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID FIRST_OCCURRENCE_DATE  \
# 0          robbery-residence             robbery       1/12/2019 16:00
# 1     theft-of-motor-vehicle          auto-theft       1/10/2019 18:30
# 2             theft-shoplift             larceny       1/12/2019 11:30
# 3  criminal-mischief-mtr-veh     public-disorder       1/12/2019 13:40
# 4  drug-hallucinogen-possess        drug-alcohol       1/13/2019 22:13
#
#   LAST_OCCURRENCE_DATE    REPORTED_DATE           INCIDENT_ADDRESS      GEO_X  \
# ...

# %%
crime_1_df = crime_df[crime_df.OFFENSE_CATEGORY_ID != 'traffic-accident']
crime_1_df.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0  2.019279e+08  2.020000e+14          1208                       0
# 1  2.019238e+08  2.020000e+14          2404                       0
# 2  2.019260e+08  2.020000e+14          2303                       0
# 3  2.019600e+10  2.020000e+16          2999                       1
# 4  2.019291e+08  2.020000e+14          3504                       0
#
#              OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID FIRST_OCCURRENCE_DATE  \
# 0          robbery-residence             robbery       1/12/2019 16:00
# 1     theft-of-motor-vehicle          auto-theft       1/10/2019 18:30
# 2             theft-shoplift             larceny       1/12/2019 11:30
# 3  criminal-mischief-mtr-veh     public-disorder       1/12/2019 13:40
# 4  drug-hallucinogen-possess        drug-alcohol       1/13/2019 22:13
#
#   LAST_OCCURRENCE_DATE    REPORTED_DATE           INCIDENT_ADDRESS      GEO_X  \
# ...

# %%
# denver crime data cleaned up by filtering columns
crime_2_df = crime_df[['INCIDENT_ID', 'OFFENSE_ID', 'OFFENSE_CODE', 'OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'REPORTED_DATE', 'GEO_LON', 'GEO_LAT', 'NEIGHBORHOOD_ID']]
crime_2_df.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE            OFFENSE_TYPE_ID  \
# 0  2.019279e+08  2.020000e+14          1208          robbery-residence
# 1  2.019238e+08  2.020000e+14          2404     theft-of-motor-vehicle
# 2  2.019260e+08  2.020000e+14          2303             theft-shoplift
# 3  2.019600e+10  2.020000e+16          2999  criminal-mischief-mtr-veh
# 4  2.019291e+08  2.020000e+14          3504  drug-hallucinogen-possess
#
#   OFFENSE_CATEGORY_ID    REPORTED_DATE     GEO_LON    GEO_LAT NEIGHBORHOOD_ID
# 0             robbery  1/13/2019 14:41 -104.888750  39.739854     east-colfax
# 1          auto-theft  1/11/2019 10:06 -105.031119  39.764540   west-highland
# 2             larceny  1/12/2019 12:01 -104.959055  39.740330       city-park
# 3     public-disorder  1/12/2019 14:04 -104.825985  39.797799       montbello
# 4        drug-alcohol  1/13/2019 23:46 -105.015348  39.730808    lincoln-park

# %%
# number of crimes in denver per category (not sure difference between incident id and offense id)
crimes_by_category_df = crime_2_df.groupby('OFFENSE_CATEGORY_ID')[['INCIDENT_ID', 'OFFENSE_ID']].nunique()
crimes_by_category_df
# Out:
#                               INCIDENT_ID  OFFENSE_ID
# OFFENSE_CATEGORY_ID
# aggravated-assault                   1062           5
# all-other-crimes                     4805           7
# arson                                  47           4
# auto-theft                           2583           5
# burglary                             1688           5
# drug-alcohol                         2387           5
# larceny                              4471           5
# murder                                 27           3
# other-crimes-against-persons         2197           6
# public-disorder                      3711           6
# robbery                               530           5
# sexual-assault                        400           4
# theft-from-motor-vehicle             3721           5
# white-collar-crime                    621           4

# %%
# number of crimes per neighborhood (sorted least reported crime to most)
crimes_by_neighborhood_df = crime_2_df.groupby('NEIGHBORHOOD_ID')[['INCIDENT_ID', 'OFFENSE_ID']].nunique()
crimes_by_neighborhood_df.sort_values('OFFENSE_ID').head()
# Out:
#                  INCIDENT_ID  OFFENSE_ID
# NEIGHBORHOOD_ID
# wellshire                 28           3
# city-park                174           3
# barnum-west              180           3
# country-club              51           3
# jefferson-park           215           4

# %%
# number of crimes per neighborhood (viewing 5 neighborhoods with highest numbers of reported crimes)
crimes_by_neighborhood_df.sort_values('OFFENSE_ID').tail()
# Out:
#                    INCIDENT_ID  OFFENSE_ID
# NEIGHBORHOOD_ID
# athmar-park                295           5
# montbello                  914           6
# east-colfax                640           6
# barnum                     240           6
# harvey-park-south          219           6

# %%
pd.set_option('display.max_columns', None)
listings_gz_df = pd.read_csv('listings.csv.gz', compression = 'gzip', header = 0, sep = ',', quotechar = '"')
listings_gz_df.neighbourhood = listings_gz_df.neighbourhood.str.lower()
listings_gz_df.neighbourhood_cleansed = listings_gz_df.neighbourhood_cleansed.str.lower()
listings_gz_df.host_neighbourhood = listings_gz_df.host_neighbourhood.str.lower()
listings_gz_df.head()
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  177  https://www.airbnb.com/rooms/177  20190427155417   2019-04-27
# 1  360  https://www.airbnb.com/rooms/360  20190427155417   2019-04-27
# 2  590  https://www.airbnb.com/rooms/590  20190427155417   2019-04-27
# 3  592  https://www.airbnb.com/rooms/592  20190427155417   2019-04-27
# 4  686  https://www.airbnb.com/rooms/686  20190427155417   2019-04-27
#
#                                                name  \
# 0  Tiny Home in the Heart of the City- ECO FRIENDLY
# 1       LoHi Secret garden at the Chickadee Cottage
# 2                 Comfortable  - and a great value!
# 3                                           private
# 4                 Alexandra's Uptown Queen Bed Room
#
#                                              summary  \
# 0  160 sq ft + 80 sq ft loft for sleeping, Sleeps...
# 1  Come enjoy our oasis is the city and stay at o...
# 2  Large guest room in my home, where I also live...
# ...

# %%
list(listings_gz_df)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
listings_df = pd.read_csv('listings.csv')
listings_df.neighbourhood = listings_df.neighbourhood.str.lower()
listings_df.head()
# Out:
#     id                                              name  host_id  \
# 0  177  Tiny Home in the Heart of the City- ECO FRIENDLY      615
# 1  360       LoHi Secret garden at the Chickadee Cottage      666
# 2  590                 Comfortable  - and a great value!      933
# 3  592                                           private      933
# 4  686                 Alexandra's Uptown Queen Bed Room      990
#
#              host_name  neighbourhood_group       neighbourhood  latitude  \
# 0                  Joe                  NaN    virginia village  39.69585
# 1  Jennifer & Giovanni                  NaN            highland  39.76703
# 2                 Jill                  NaN     north park hill  39.75361
# 3                 Jill                  NaN     north park hill  39.75438
# 4            Alexandra                  NaN  north capitol hill  39.74503
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
denver_2019_crime_df = pd.read_csv('denver_2019_crime.csv')

# %%
denver_2019_crime_df = denver_2019_crime_df[denver_2019_crime_df.OFFENSE_CATEGORY_ID != 'traffic-accident']

# %%
# denver crime data cleaned up by filtering columns
crime_2_df = crime_df[['INCIDENT_ID', 'OFFENSE_ID', 'OFFENSE_CODE', 'OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'REPORTED_DATE', 'GEO_LON', 'GEO_LAT', 'NEIGHBORHOOD_ID']]
crime_2_df.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE            OFFENSE_TYPE_ID  \
# 0  2.019279e+08  2.020000e+14          1208          robbery-residence
# 1  2.019238e+08  2.020000e+14          2404     theft-of-motor-vehicle
# 2  2.019260e+08  2.020000e+14          2303             theft-shoplift
# 3  2.019600e+10  2.020000e+16          2999  criminal-mischief-mtr-veh
# 4  2.019291e+08  2.020000e+14          3504  drug-hallucinogen-possess
#
#   OFFENSE_CATEGORY_ID    REPORTED_DATE     GEO_LON    GEO_LAT NEIGHBORHOOD_ID
# 0             robbery  1/13/2019 14:41 -104.888750  39.739854     east-colfax
# 1          auto-theft  1/11/2019 10:06 -105.031119  39.764540   west-highland
# 2             larceny  1/12/2019 12:01 -104.959055  39.740330       city-park
# 3     public-disorder  1/12/2019 14:04 -104.825985  39.797799       montbello
# 4        drug-alcohol  1/13/2019 23:46 -105.015348  39.730808    lincoln-park

# %%
# number of crimes in denver per category (not sure difference between incident id and offense id)
crimes_by_category_df = crime_2_df.groupby('OFFENSE_CATEGORY_ID')[['INCIDENT_ID', 'OFFENSE_ID']].nunique()
crimes_by_category_df
# Out:
#                               INCIDENT_ID  OFFENSE_ID
# OFFENSE_CATEGORY_ID
# aggravated-assault                   1062           5
# all-other-crimes                     4805           7
# arson                                  47           4
# auto-theft                           2583           5
# burglary                             1688           5
# drug-alcohol                         2387           5
# larceny                              4471           5
# murder                                 27           3
# other-crimes-against-persons         2197           6
# public-disorder                      3711           6
# robbery                               530           5
# sexual-assault                        400           4
# theft-from-motor-vehicle             3721           5
# white-collar-crime                    621           4

# %%
# number of crimes per neighborhood (sorted least reported crime to most)
crimes_by_neighborhood_df = crime_2_df.groupby('NEIGHBORHOOD_ID')[['INCIDENT_ID', 'OFFENSE_ID']].nunique()
crimes_by_neighborhood_df.sort_values('OFFENSE_ID').head()
# Out:
#                  INCIDENT_ID  OFFENSE_ID
# NEIGHBORHOOD_ID
# wellshire                 28           3
# city-park                174           3
# barnum-west              180           3
# country-club              51           3
# jefferson-park           215           4

# %%
# number of crimes per neighborhood (viewing 5 neighborhoods with highest numbers of reported crimes)
crimes_by_neighborhood_df.sort_values('OFFENSE_ID').tail()
# Out:
#                    INCIDENT_ID  OFFENSE_ID
# NEIGHBORHOOD_ID
# athmar-park                295           5
# montbello                  914           6
# east-colfax                640           6
# barnum                     240           6
# harvey-park-south          219           6

# %%
pd.set_option('display.max_columns', None)
listings_gz_df = pd.read_csv('listings.csv.gz', compression = 'gzip', header = 0, sep = ',', quotechar = '"')
listings_gz_df.neighbourhood = listings_gz_df.neighbourhood.str.lower()
listings_gz_df.neighbourhood_cleansed = listings_gz_df.neighbourhood_cleansed.str.lower()
listings_gz_df.host_neighbourhood = listings_gz_df.host_neighbourhood.str.lower()
listings_gz_df.head()
# Out:
#     id                       listing_url       scrape_id last_scraped  \
# 0  177  https://www.airbnb.com/rooms/177  20190427155417   2019-04-27
# 1  360  https://www.airbnb.com/rooms/360  20190427155417   2019-04-27
# 2  590  https://www.airbnb.com/rooms/590  20190427155417   2019-04-27
# 3  592  https://www.airbnb.com/rooms/592  20190427155417   2019-04-27
# 4  686  https://www.airbnb.com/rooms/686  20190427155417   2019-04-27
#
#                                                name  \
# 0  Tiny Home in the Heart of the City- ECO FRIENDLY
# 1       LoHi Secret garden at the Chickadee Cottage
# 2                 Comfortable  - and a great value!
# 3                                           private
# 4                 Alexandra's Uptown Queen Bed Room
#
#                                              summary  \
# 0  160 sq ft + 80 sq ft loft for sleeping, Sleeps...
# 1  Come enjoy our oasis is the city and stay at o...
# 2  Large guest room in my home, where I also live...
# ...

# %%
list(listings_gz_df)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
# ...

# %%
listings_df = pd.read_csv('listings.csv')
listings_df.neighbourhood = listings_df.neighbourhood.str.lower()
listings_df.head()
# Out:
#     id                                              name  host_id  \
# 0  177  Tiny Home in the Heart of the City- ECO FRIENDLY      615
# 1  360       LoHi Secret garden at the Chickadee Cottage      666
# 2  590                 Comfortable  - and a great value!      933
# 3  592                                           private      933
# 4  686                 Alexandra's Uptown Queen Bed Room      990
#
#              host_name  neighbourhood_group       neighbourhood  latitude  \
# 0                  Joe                  NaN    virginia village  39.69585
# 1  Jennifer & Giovanni                  NaN            highland  39.76703
# 2                 Jill                  NaN     north park hill  39.75361
# 3                 Jill                  NaN     north park hill  39.75438
# 4            Alexandra                  NaN  north capitol hill  39.74503
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
denver_2019_crime_df = pd.read_csv('denver_2019_crime.csv')

# %%
denver_2019_crime_df = denver_2019_crime_df[denver_2019_crime_df.OFFENSE_CATEGORY_ID != 'traffic-accident']

# %%
denver_2019_crime_df = denver_2019_crime_df[denver_2019_crime_df.OFFENSE_CATEGORY_ID != 'white-collar-crime']

# %%
denver_2019_crime_df.NEIGHBORHOOD_ID = denver_2019_crime_df.NEIGHBORHOOD_ID.str.replace("-"," ")

# %%
denver_2019_crime_df = denver_2019_crime_df.drop(columns=['OFFENSE_CODE_EXTENSION'])

# %%
denver_2019_crime_df.head()
# Out:
#     INCIDENT_ID    OFFENSE_ID  OFFENSE_CODE            OFFENSE_TYPE_ID  \
# 0  2.019279e+08  2.020000e+14          1208          robbery-residence
# 1  2.019238e+08  2.020000e+14          2404     theft-of-motor-vehicle
# 2  2.019260e+08  2.020000e+14          2303             theft-shoplift
# 3  2.019600e+10  2.020000e+16          2999  criminal-mischief-mtr-veh
# 4  2.019291e+08  2.020000e+14          3504  drug-hallucinogen-possess
#
#   OFFENSE_CATEGORY_ID FIRST_OCCURRENCE_DATE LAST_OCCURRENCE_DATE  \
# 0             robbery       1/12/2019 16:00      1/12/2019 19:00
# 1          auto-theft       1/10/2019 18:30       1/11/2019 9:00
# 2             larceny       1/12/2019 11:30                  NaN
# 3     public-disorder       1/12/2019 13:40      1/12/2019 13:40
# 4        drug-alcohol       1/13/2019 22:13                  NaN
#
#      REPORTED_DATE           INCIDENT_ADDRESS      GEO_X      GEO_Y  \
# 0  1/13/2019 14:41                        NaN  3171896.0  1694950.0
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///all_denver_data.sqlite')

denver_2019_crime_df.to_sql(name='crime_2019', con=engine, if_exists='append', index=False)
reviews_gz_df.to_sql(name='reviews',con=engine, if_exists='append', index = False)
calendar_gz_df.to_sql(name='calendar',con=engine, if_exists='append', index = False)
listings_gz_df.to_sql(name='listings',con=engine, if_exists='append', index = False)
